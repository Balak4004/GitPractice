# %%
import pandas as pd
from sqlalchemy import create_engine
import cx_Oracle

# %%
mysql_engine = create_engine('oracle+cx_oracle://hr:hr@localhost:1521/xe')
connection = mysql_engine.connect()

# %%
df = pd.read_sql("select * from employees", connection)

# %%
df
# Out:
#      employee_id first_name last_name     email  phone_number  hire_date  \
# 0            100     Steven      King     SKING  515.123.4567 2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567 2006-01-03
# 4            104      Bruce     Ernst    BERNST  590.423.4568 2007-05-21
# ..           ...        ...       ...       ...           ...        ...
# 102          202        Pat       Fay      PFAY  603.123.6666 2005-08-17
# 103          203      Susan    Mavris   SMAVRIS  515.123.7777 2002-06-07
# 104          204    Hermann      Baer     HBAER  515.123.8888 2002-06-07
# 105          205    Shelley   Higgins  SHIGGINS  515.123.8080 2002-06-07
# 106          206    William     Gietz    WGIETZ  515.123.8181 2002-06-07
#
#          job_id   salary  commission_pct  manager_id  department_id
# ...

# %%
rec_count = len(df)

# %%
rec_count
# Out:
# 107

# %%
rec_count1 = df.shape[0]
rec_count1
# Out:
# 107

# %%
dup_jobid = df.groupby('job_id').size().reset_index(name='dupcount')
dup_jobid
# Out:
#         job_id  dupcount
# 0   AC_ACCOUNT         1
# 1       AC_MGR         1
# 2      AD_ASST         1
# 3      AD_PRES         1
# 4        AD_VP         2
# 5   FI_ACCOUNT         5
# 6       FI_MGR         1
# 7       HR_REP         1
# 8      IT_PROG         5
# 9       MK_MAN         1
# 10      MK_REP         1
# 11      PR_REP         1
# 12    PU_CLERK         5
# 13      PU_MAN         1
# 14      SA_MAN         5
# 15      SA_REP        30
# 16    SH_CLERK        20
# 17    ST_CLERK        20
# 18      ST_MAN         5

# %%
dup_rec = dup_jobid[dup_jobid['dupcount']>1].sort_values(by='dupcount', ascending=True)
dup_rec
# Out:
#         job_id  dupcount
# 4        AD_VP         2
# 5   FI_ACCOUNT         5
# 8      IT_PROG         5
# 12    PU_CLERK         5
# 14      SA_MAN         5
# 18      ST_MAN         5
# 17    ST_CLERK        20
# 16    SH_CLERK        20
# 15      SA_REP        30

# %%
dup_rec = df[df['job_id'].isin(dup_jobid[dup_jobid['dupcount']>1]['job_id'])]
dup_rec
# Out:
#     employee_id first_name last_name     email  phone_number  hire_date  \
# 1           101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 2           102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13
# 3           103  Alexander    Hunold   AHUNOLD  590.423.4567 2006-01-03
# 4           104      Bruce     Ernst    BERNST  590.423.4568 2007-05-21
# 5           105      David    Austin   DAUSTIN  590.423.4569 2005-06-25
# ..          ...        ...       ...       ...           ...        ...
# 95          195      Vance     Jones    VJONES  650.501.4876 2007-03-17
# 96          196      Alana     Walsh    AWALSH  650.507.9811 2006-04-24
# 97          197      Kevin    Feeney   KFEENEY  650.507.9822 2006-05-23
# 98          198     Donald  OConnell  DOCONNEL  650.507.9833 2007-06-21
# 99          199    Douglas     Grant    DGRANT  650.507.9844 2008-01-13
#
#       job_id   salary  commission_pct  manager_id  department_id  dupcount
# ...

# %%
dup_rec1 = dup_jobid[dup_jobid['dupcount']==5]
dup_rec1
# Out:
#         job_id  dupcount
# 5   FI_ACCOUNT         5
# 8      IT_PROG         5
# 12    PU_CLERK         5
# 14      SA_MAN         5
# 18      ST_MAN         5

# %%
dup_jobid = df.groupby('job_id').size().reset_index(name='dupcount')
duprec = dup_jobid[dup_jobid['dupcount']==5]
duprec1 = df[df['job_id'].isin(duprec['job_id'])]
duprec1
# Out:
#     employee_id   first_name   last_name     email        phone_number  \
# 3           103    Alexander      Hunold   AHUNOLD        590.423.4567
# 4           104        Bruce       Ernst    BERNST        590.423.4568
# 5           105        David      Austin   DAUSTIN        590.423.4569
# 6           106        Valli   Pataballa  VPATABAL        590.423.4560
# 7           107        Diana     Lorentz  DLORENTZ        590.423.5567
# 9           109       Daniel      Faviet   DFAVIET        515.124.4169
# 10          110         John        Chen     JCHEN        515.124.4269
# 11          111       Ismael     Sciarra  ISCIARRA        515.124.4369
# 12          112  Jose Manuel       Urman   JMURMAN        515.124.4469
# 13          113         Luis        Popp     LPOPP        515.124.4567
# 15          115    Alexander        Khoo     AKHOO        515.127.4562
# 16          116       Shelli       Baida    SBAIDA        515.127.4563
# ...

# %%
# AND operator &

# %%
dup_jobid = df.groupby('job_id').size().reset_index(name='dupcount')
duprec = dup_jobid[dup_jobid['dupcount']==2]
duprec1 = df[df['job_id'].isin(duprec['job_id']) & (df['job_id'] == 'ST_MAN')]
duprec1
# Out:
#     employee_id first_name last_name     email  phone_number  hire_date  \
# 1           101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 2           102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13
# 20          120    Matthew     Weiss    MWEISS  650.123.1234 2004-07-18
# 21          121       Adam     Fripp    AFRIPP  650.123.2234 2005-04-10
# 22          122      Payam  Kaufling  PKAUFLIN  650.123.3234 2003-05-01
# 23          123     Shanta   Vollman  SVOLLMAN  650.123.4234 2005-10-10
# 24          124      Kevin   Mourgos  KMOURGOS  650.123.5234 2007-11-16
#
#     job_id   salary  commission_pct  manager_id  department_id  dupcount
# 1    AD_VP  17000.0             NaN       100.0           90.0         2
# 2    AD_VP  17000.0             NaN       100.0           90.0         2
# 20  ST_MAN   8000.0             NaN       100.0           50.0         5
# 21  ST_MAN   8200.0             NaN       100.0           50.0         5
# ...

# %%
# OR Operator |

# %%
dup_jobid = df.groupby('job_id').size().reset_index(name='dupcount')
duprec = dup_jobid[dup_jobid['dupcount']==2]
duprec1 = df[df['job_id'].isin(duprec['job_id']) | (df['job_id'] == 'ST_MAN')]
duprec1

# %%
nulls = df.isnull()
nulls
# Out:
#      employee_id  first_name  last_name  email  phone_number  hire_date  \
# 0          False       False      False  False         False      False
# 1          False       False      False  False         False      False
# 2          False       False      False  False         False      False
# 3          False       False      False  False         False      False
# 4          False       False      False  False         False      False
# ..           ...         ...        ...    ...           ...        ...
# 102        False       False      False  False         False      False
# 103        False       False      False  False         False      False
# 104        False       False      False  False         False      False
# 105        False       False      False  False         False      False
# 106        False       False      False  False         False      False
#
#      job_id  salary  commission_pct  manager_id  department_id
# ...

# %%
null_col = df.columns[df.isnull().any()]
null_col
# Out:
# Index(['commission_pct', 'manager_id', 'department_id'], dtype='object')

# %%
null_rows = df[df.isnull().any(axis=1)]
null_rows
# Out:
#      employee_id first_name last_name     email  phone_number  hire_date  \
# 0            100     Steven      King     SKING  515.123.4567 2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567 2006-01-03
# 4            104      Bruce     Ernst    BERNST  590.423.4568 2007-05-21
# ..           ...        ...       ...       ...           ...        ...
# 102          202        Pat       Fay      PFAY  603.123.6666 2005-08-17
# 103          203      Susan    Mavris   SMAVRIS  515.123.7777 2002-06-07
# 104          204    Hermann      Baer     HBAER  515.123.8888 2002-06-07
# 105          205    Shelley   Higgins  SHIGGINS  515.123.8080 2002-06-07
# 106          206    William     Gietz    WGIETZ  515.123.8181 2002-06-07
#
#          job_id   salary  commission_pct  manager_id  department_id
# ...

# %%
null_specific_col = df['manager_id'].isnull().any()
null_specific_col
# Out:
# np.True_

# %%
null_specific_col1 = df[df['manager_id'].isnull()]
null_specific_col1
# Out:
#    employee_id first_name last_name  email  phone_number  hire_date   job_id  \
# 0          100     Steven      King  SKING  515.123.4567 2003-06-17  AD_PRES
#
#     salary  commission_pct  manager_id  department_id
# 0  24000.0             NaN         NaN           90.0

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File H:\pythonprojects\myProj\.venv\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'null_specific_col'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[50], line 1
# ----> 1 df1 = df['null_specific_col']
#
# ...

# %%
null_specific_col = df['commission_pct'].isnull().sum()
null_specific_col
# Out:
# np.int64(72)
