# %%
import pandas as pd
from sqlalchemy import create_engine
import cx_Oracle

# %%
mysql_engine = create_engine('oracle+cx_oracle://hr:hr@localhost:1521/xe')
connection = mysql_engine.connect()

# %%
df1 = pd.read_sql("select * from employees", connection)

# %%
df1
# Out:
#      employee_id first_name last_name     email  phone_number  hire_date  \
# 0            100     Steven      King     SKING  515.123.4567 2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567 2006-01-03
# 4            104      Bruce     Ernst    BERNST  590.423.4568 2007-05-21
# ..           ...        ...       ...       ...           ...        ...
# 102          202        Pat       Fay      PFAY  603.123.6666 2005-08-17
# 103          203      Susan    Mavris   SMAVRIS  515.123.7777 2002-06-07
# 104          204    Hermann      Baer     HBAER  515.123.8888 2002-06-07
# 105          205    Shelley   Higgins  SHIGGINS  515.123.8080 2002-06-07
# 106          206    William     Gietz    WGIETZ  515.123.8181 2002-06-07
#
#          job_id   salary  commission_pct  manager_id  department_id
# ...

# %%
df2 = pd.read_sql("select * from departments", connection)
df2
# Out:
#     department_id       department_name  manager_id  location_id
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# ...

# %%
join_df = df1.merge(df2, on='department_id', how='inner', suffixes=('_left','_right'))
join_df
# Out:
#      employee_id first_name last_name     email  phone_number  hire_date  \
# 0            100     Steven      King     SKING  515.123.4567 2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567 2006-01-03
# 4            104      Bruce     Ernst    BERNST  590.423.4568 2007-05-21
# ..           ...        ...       ...       ...           ...        ...
# 101          202        Pat       Fay      PFAY  603.123.6666 2005-08-17
# 102          203      Susan    Mavris   SMAVRIS  515.123.7777 2002-06-07
# 103          204    Hermann      Baer     HBAER  515.123.8888 2002-06-07
# 104          205    Shelley   Higgins  SHIGGINS  515.123.8080 2002-06-07
# 105          206    William     Gietz    WGIETZ  515.123.8181 2002-06-07
#
#          job_id   salary  commission_pct  manager_id_left  department_id  \
# ...

# %%
join_df[join_df['email']=='SKING']
# Out:
#    employee_id first_name last_name  email  phone_number  hire_date   job_id  \
# 0          100     Steven      King  SKING  515.123.4567 2003-06-17  AD_PRES
#
#     salary  commission_pct  manager_id_left  department_id department_name  \
# 0  24000.0             NaN              NaN           90.0       Executive
#
#    manager_id_right  location_id
# 0             100.0         1700

# %%
join_df[join_df['department_id']==90]
# Out:
#    employee_id first_name last_name     email  phone_number  hire_date  \
# 0          100     Steven      King     SKING  515.123.4567 2003-06-17
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13
#
#     job_id   salary  commission_pct  manager_id_left  department_id  \
# 0  AD_PRES  24000.0             NaN              NaN           90.0
# 1    AD_VP  17000.0             NaN            100.0           90.0
# 2    AD_VP  17000.0             NaN            100.0           90.0
#
#   department_name  manager_id_right  location_id
# 0       Executive             100.0         1700
# 1       Executive             100.0         1700
# 2       Executive             100.0         1700

# %%
join_df[(join_df['department_id']==90) & (join_df['first_name']=='Lex')]
# Out:
#    employee_id first_name last_name    email  phone_number  hire_date job_id  \
# 2          102        Lex   De Haan  LDEHAAN  515.123.4569 2001-01-13  AD_VP
#
#     salary  commission_pct  manager_id_left  department_id department_name  \
# 2  17000.0             NaN            100.0           90.0       Executive
#
#    manager_id_right  location_id
# 2             100.0         1700

# %%
join_df[(join_df['department_id']==90) | (join_df['first_name']=='Pat')]
# Out:
#      employee_id first_name last_name     email  phone_number  hire_date  \
# 0            100     Steven      King     SKING  515.123.4567 2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13
# 101          202        Pat       Fay      PFAY  603.123.6666 2005-08-17
#
#       job_id   salary  commission_pct  manager_id_left  department_id  \
# 0    AD_PRES  24000.0             NaN              NaN           90.0
# 1      AD_VP  17000.0             NaN            100.0           90.0
# 2      AD_VP  17000.0             NaN            100.0           90.0
# 101   MK_REP   6000.0             NaN            201.0           20.0
#
#     department_name  manager_id_right  location_id
# 0         Executive             100.0         1700
# 1         Executive             100.0         1700
# 2         Executive             100.0         1700
# ...

# %%
joindf1 = join_df[['employee_id', 'first_name','last_name','department_id','department_name']]
joindf1
# Out:
#      employee_id first_name last_name  department_id   department_name
# 0            100     Steven      King           90.0         Executive
# 1            101      Neena   Kochhar           90.0         Executive
# 2            102        Lex   De Haan           90.0         Executive
# 3            103  Alexander    Hunold           60.0                IT
# 4            104      Bruce     Ernst           60.0                IT
# ..           ...        ...       ...            ...               ...
# 101          202        Pat       Fay           20.0         Marketing
# 102          203      Susan    Mavris           40.0   Human Resources
# 103          204    Hermann      Baer           70.0  Public Relations
# 104          205    Shelley   Higgins          110.0        Accounting
# 105          206    William     Gietz          110.0        Accounting
#
# [106 rows x 5 columns]

# %%
joindf1[(joindf1['employee_id'].isin([100,101,102])) ]
# Out:
#    employee_id first_name last_name  department_id department_name
# 0          100     Steven      King           90.0       Executive
# 1          101      Neena   Kochhar           90.0       Executive
# 2          102        Lex   De Haan           90.0       Executive

# %%
joindf1[(joindf1['employee_id'].isin([100,101,102])) & (joindf1['department_id']==60)]
# Out:
# Empty DataFrame
# Columns: [employee_id, first_name, last_name, department_id, department_name]
# Index: []

# %%
joindf1[(joindf1['department_id']==90) & (join_df['first_name']=='Lex')]
joindf1
# Out:
#      employee_id first_name last_name  department_id   department_name
# 0            100     Steven      King           90.0         Executive
# 1            101      Neena   Kochhar           90.0         Executive
# 2            102        Lex   De Haan           90.0         Executive
# 3            103  Alexander    Hunold           60.0                IT
# 4            104      Bruce     Ernst           60.0                IT
# ..           ...        ...       ...            ...               ...
# 101          202        Pat       Fay           20.0         Marketing
# 102          203      Susan    Mavris           40.0   Human Resources
# 103          204    Hermann      Baer           70.0  Public Relations
# 104          205    Shelley   Higgins          110.0        Accounting
# 105          206    William     Gietz          110.0        Accounting
#
# [106 rows x 5 columns]

# %%
df2 = pd.read_sql("select * from employees where first_name ='Lex'", connection)

# %%
df2
# Out:
#    employee_id first_name last_name    email  phone_number  hire_date job_id  \
# 0          102        Lex   De Haan  LDEHAAN  515.123.4569 2001-01-13  AD_VP
#
#     salary commission_pct  manager_id  department_id
# 0  17000.0           None         100             90

# %%
df2
# Out:
#     department_id       department_name  manager_id  location_id
# 0              10        Administration       200.0         1700
# 1              20             Marketing       201.0         1800
# 2              30            Purchasing       114.0         1700
# 3              40       Human Resources       203.0         2400
# 4              50              Shipping       121.0         1500
# 5              60                    IT       103.0         1400
# 6              70      Public Relations       204.0         2700
# 7              80                 Sales       145.0         2500
# 8              90             Executive       100.0         1700
# 9             100               Finance       108.0         1700
# 10            110            Accounting       205.0         1700
# 11            120              Treasury         NaN         1700
# 12            130         Corporate Tax         NaN         1700
# ...

# %%
df3 = df2.rename(columns={'department_id':'dept_id'})

# %%
df3
# Out:
#     dept_id       department_name  manager_id  location_id
# 0        10        Administration       200.0         1700
# 1        20             Marketing       201.0         1800
# 2        30            Purchasing       114.0         1700
# 3        40       Human Resources       203.0         2400
# 4        50              Shipping       121.0         1500
# 5        60                    IT       103.0         1400
# 6        70      Public Relations       204.0         2700
# 7        80                 Sales       145.0         2500
# 8        90             Executive       100.0         1700
# 9       100               Finance       108.0         1700
# 10      110            Accounting       205.0         1700
# 11      120              Treasury         NaN         1700
# 12      130         Corporate Tax         NaN         1700
# 13      140    Control And Credit         NaN         1700
# 14      150  Shareholder Services         NaN         1700
# ...

# %%
joindf3 = df1.merge(df3,left_on='department_id', right_on='dept_id', how='inner', suffixes=('_emp', '_dept'))

# %%
joindf3
# Out:
#      employee_id first_name last_name     email  phone_number  hire_date  \
# 0            100     Steven      King     SKING  515.123.4567 2003-06-17
# 1            101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21
# 2            102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13
# 3            103  Alexander    Hunold   AHUNOLD  590.423.4567 2006-01-03
# 4            104      Bruce     Ernst    BERNST  590.423.4568 2007-05-21
# ..           ...        ...       ...       ...           ...        ...
# 101          202        Pat       Fay      PFAY  603.123.6666 2005-08-17
# 102          203      Susan    Mavris   SMAVRIS  515.123.7777 2002-06-07
# 103          204    Hermann      Baer     HBAER  515.123.8888 2002-06-07
# 104          205    Shelley   Higgins  SHIGGINS  515.123.8080 2002-06-07
# 105          206    William     Gietz    WGIETZ  515.123.8181 2002-06-07
#
#          job_id   salary  commission_pct  manager_id_emp  department_id  \
# ...

# %%
joindf3[joindf3['job_id']=='AD_VP']
# Out:
#    employee_id first_name last_name     email  phone_number  hire_date job_id  \
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21  AD_VP
# 2          102        Lex   De Haan   LDEHAAN  515.123.4569 2001-01-13  AD_VP
#
#     salary  commission_pct  manager_id_emp  department_id  dept_id  \
# 1  17000.0             NaN           100.0           90.0       90
# 2  17000.0             NaN           100.0           90.0       90
#
#   department_name  manager_id_dept  location_id
# 1       Executive            100.0         1700
# 2       Executive            100.0         1700

# %%
joindf3[(joindf3['job_id']=='AD_VP') & (joindf3['hire_date']>'2004-09-21')]
# Out:
#    employee_id first_name last_name     email  phone_number  hire_date job_id  \
# 1          101      Neena   Kochhar  NKOCHHAR  515.123.4568 2005-09-21  AD_VP
#
#     salary  commission_pct  manager_id_emp  department_id  dept_id  \
# 1  17000.0             NaN           100.0           90.0       90
#
#   department_name  manager_id_dept  location_id
# 1       Executive            100.0         1700

# %%
# using filter

# %%
joindf4 = joindf3.filter(items=['employee_id','first_name','last_name'])

# %%
joindf4
# Out:
#      employee_id first_name last_name
# 0            100     Steven      King
# 1            101      Neena   Kochhar
# 2            102        Lex   De Haan
# 3            103  Alexander    Hunold
# 4            104      Bruce     Ernst
# ..           ...        ...       ...
# 101          202        Pat       Fay
# 102          203      Susan    Mavris
# 103          204    Hermann      Baer
# 104          205    Shelley   Higgins
# 105          206    William     Gietz
#
# [106 rows x 3 columns]
